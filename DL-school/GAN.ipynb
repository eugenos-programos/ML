# %% [markdown]
# <p style="align: center;"><img align=center src="https://drive.google.com/uc?export=view&id=1I8kDikouqpH4hf7JBiSYAeNT2IO52T-T" width=600 height=480/></p>
# <h3 style="text-align: center;"><b>Школа глубокого обучения ФПМИ МФТИ</b></h3>
#
# <h3 style="text-align: center;"><b>Домашнее задание. Generative adversarial networks</b></h3>

# %% [markdown]
# В этом домашнем задании вы обучите GAN генерировать лица людей и посмотрите на то, как можно оценивать качество генерации

# %%
rm -r ./04000
# Out:
# rm: cannot remove './04000': No such file or directory

# %%
import os
from torch.utils.data import DataLoader
from torchvision.datasets import ImageFolder
import torchvision.transforms as tfs
import torch
import torch.nn as nn
import cv2
from tqdm.notebook import tqdm
from torchvision.utils import save_image
from torchvision.utils import make_grid
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

sns.set(style='darkgrid', font_scale=1.2)

# %% [markdown]
# ## Часть 1. Подготовка данных (1 балл)

# %% [markdown]
# В качестве обучающей выборки возьмем часть датасета [Flickr Faces](https://github.com/NVlabs/ffhq-dataset), который содержит изображения лиц людей в высоком разрешении (1024х1024). Оригинальный датасет очень большой, поэтому мы возьмем его часть. Скачать датасет можно [здесь](https://drive.google.com/file/d/1KWPc4Pa7u2TWekUvNu9rTSO0U2eOlZA9/view?usp=sharing)

# %% [markdown]
# Давайте загрузим наши изображения. Напишите функцию, которая строит DataLoader для изображений, при этом меняя их размер до нужного значения (размер 1024 слишком большой, поэтому мы рекомендуем взять размер 128 либо немного больше)

# %%
# !pip install googledrivedownloader
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: googledrivedownloader in /usr/local/lib/python3.7/dist-packages (0.4)

# %%
from google.colab import drive
drive.mount('/content/gdrive/')
# !unzip /content/gdrive/MyDrive/faces_dataset_small.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: faces_dataset_small/00490.png
#   inflating: __MACOSX/faces_dataset_small/._00490.png
#   inflating: faces_dataset_small/01956.png
#   inflating: __MACOSX/faces_dataset_small/._01956.png
#   inflating: faces_dataset_small/02287.png
#   inflating: __MACOSX/faces_dataset_small/._02287.png
#   inflating: faces_dataset_small/01765.png
#   inflating: __MACOSX/faces_dataset_small/._01765.png
#   inflating: faces_dataset_small/03614.png
#   inflating: __MACOSX/faces_dataset_small/._03614.png
#   inflating: faces_dataset_small/03600.png
#   inflating: __MACOSX/faces_dataset_small/._03600.png
#   inflating: faces_dataset_small/01771.png
#   inflating: __MACOSX/faces_dataset_small/._01771.png
#   inflating: faces_dataset_small/04609.png
#   inflating: __MACOSX/faces_dataset_small/._04609.png
#   inflating: faces_dataset_small/01981.png
#   inflating: __MACOSX/faces_dataset_small/._01981.png
#   inflating: faces_dataset_small/01759.png
#   inflating: __MACOSX/faces_dataset_small/._01759.png
#   inflating: faces_dataset_small/02250.png
#   inflating: __MACOSX/faces_dataset_small/._02250.png
#   inflating: faces_dataset_small/04621.png
#   inflating: __MACOSX/faces_dataset_small/._04621.png
#   inflating: faces_dataset_small/03628.png
#   inflating: __MACOSX/faces_dataset_small/._03628.png
#   inflating: faces_dataset_small/02522.png
#   inflating: __MACOSX/faces_dataset_small/._02522.png
#   inflating: faces_dataset_small/02244.png
#   inflating: __MACOSX/faces_dataset_small/._02244.png
#   inflating: faces_dataset_small/04635.png
#   inflating: __MACOSX/faces_dataset_small/._04635.png
#   inflating: faces_dataset_small/00453.png
#   inflating: __MACOSX/faces_dataset_small/._00453.png
#   inflating: faces_dataset_small/01995.png
#   inflating: __MACOSX/faces_dataset_small/._01995.png
#   inflating: faces_dataset_small/02913.png
#   inflating: __MACOSX/faces_dataset_small/._02913.png
#   inflating: faces_dataset_small/00862.png
#   inflating: __MACOSX/faces_dataset_small/._00862.png
#   inflating: faces_dataset_small/00876.png
#   inflating: __MACOSX/faces_dataset_small/._00876.png
#   inflating: faces_dataset_small/02907.png
#   inflating: __MACOSX/faces_dataset_small/._02907.png
#   inflating: faces_dataset_small/04386.png
#   inflating: __MACOSX/faces_dataset_small/._04386.png
#   inflating: faces_dataset_small/00686.png
#   inflating: __MACOSX/faces_dataset_small/._00686.png
#   inflating: faces_dataset_small/01598.png
#   inflating: __MACOSX/faces_dataset_small/._01598.png
#   inflating: faces_dataset_small/00692.png
#   inflating: __MACOSX/faces_dataset_small/._00692.png
#   inflating: faces_dataset_small/04392.png
#   inflating: __MACOSX/faces_dataset_small/._04392.png
#   inflating: faces_dataset_small/04379.png
#   inflating: __MACOSX/faces_dataset_small/._04379.png
#   inflating: faces_dataset_small/03416.png
#   inflating: __MACOSX/faces_dataset_small/._03416.png
#   inflating: faces_dataset_small/01567.png
#   inflating: __MACOSX/faces_dataset_small/._01567.png
#   inflating: faces_dataset_small/00679.png
#   inflating: __MACOSX/faces_dataset_small/._00679.png
#   inflating: faces_dataset_small/03370.png
#   inflating: __MACOSX/faces_dataset_small/._03370.png
#   inflating: faces_dataset_small/03364.png
#   inflating: __MACOSX/faces_dataset_small/._03364.png
#   inflating: faces_dataset_small/01573.png
#   inflating: __MACOSX/faces_dataset_small/._01573.png
#   inflating: faces_dataset_small/01215.png
#   inflating: __MACOSX/faces_dataset_small/._01215.png
#   inflating: faces_dataset_small/03402.png
#   inflating: __MACOSX/faces_dataset_small/._03402.png
#   inflating: faces_dataset_small/02734.png
#   inflating: __MACOSX/faces_dataset_small/._02734.png
#   inflating: faces_dataset_small/04345.png
#   inflating: __MACOSX/faces_dataset_small/._04345.png
#   inflating: faces_dataset_small/04423.png
#   inflating: __MACOSX/faces_dataset_small/._04423.png
#   inflating: faces_dataset_small/00889.png
#   inflating: __MACOSX/faces_dataset_small/._00889.png
#   inflating: faces_dataset_small/03358.png
#   inflating: __MACOSX/faces_dataset_small/._03358.png
#   inflating: faces_dataset_small/04437.png
#   inflating: __MACOSX/faces_dataset_small/._04437.png
#   inflating: faces_dataset_small/02720.png
#   inflating: __MACOSX/faces_dataset_small/._02720.png
#   inflating: faces_dataset_small/01229.png
#   inflating: __MACOSX/faces_dataset_small/._01229.png
#   inflating: faces_dataset_small/02867.png
#   inflating: __MACOSX/faces_dataset_small/._02867.png
#   inflating: faces_dataset_small/00916.png
#   inflating: __MACOSX/faces_dataset_small/._00916.png
#   inflating: faces_dataset_small/00902.png
#   inflating: __MACOSX/faces_dataset_small/._00902.png
#   inflating: faces_dataset_small/02873.png
#   inflating: __MACOSX/faces_dataset_small/._02873.png
#   inflating: faces_dataset_small/02683.png
#   inflating: __MACOSX/faces_dataset_small/._02683.png
#   inflating: faces_dataset_small/02697.png
#   inflating: __MACOSX/faces_dataset_small/._02697.png
#   inflating: faces_dataset_small/03589.png
#   inflating: __MACOSX/faces_dataset_small/._03589.png
#   inflating: faces_dataset_small/03562.png
#   inflating: __MACOSX/faces_dataset_small/._03562.png
#   inflating: faces_dataset_small/01375.png
#   inflating: __MACOSX/faces_dataset_small/._01375.png
#   inflating: faces_dataset_small/01413.png
#   inflating: __MACOSX/faces_dataset_small/._01413.png
#   inflating: faces_dataset_small/00719.png
#   inflating: __MACOSX/faces_dataset_small/._00719.png
#   inflating: faces_dataset_small/01407.png
#   inflating: __MACOSX/faces_dataset_small/._01407.png
#   inflating: faces_dataset_small/01361.png
#   inflating: __MACOSX/faces_dataset_small/._01361.png
#   inflating: faces_dataset_small/04219.png
#   inflating: __MACOSX/faces_dataset_small/._04219.png
#   inflating: faces_dataset_small/02668.png
#   inflating: __MACOSX/faces_dataset_small/._02668.png
#   inflating: faces_dataset_small/01349.png
#   inflating: __MACOSX/faces_dataset_small/._01349.png
#   inflating: faces_dataset_small/02898.png
#   inflating: __MACOSX/faces_dataset_small/._02898.png
#   inflating: faces_dataset_small/04557.png
#   inflating: __MACOSX/faces_dataset_small/._04557.png
#   inflating: faces_dataset_small/02132.png
#   inflating: __MACOSX/faces_dataset_small/._02132.png
#   inflating: faces_dataset_small/04543.png
#   inflating: __MACOSX/faces_dataset_small/._04543.png
#   inflating: faces_dataset_small/02654.png
#   inflating: __MACOSX/faces_dataset_small/._02654.png
#   inflating: faces_dataset_small/04972.png
#   inflating: __MACOSX/faces_dataset_small/._04972.png
#   inflating: faces_dataset_small/04966.png
#   inflating: __MACOSX/faces_dataset_small/._04966.png
#   inflating: faces_dataset_small/04796.png
#   inflating: __MACOSX/faces_dataset_small/._04796.png
#   inflating: faces_dataset_small/01836.png
#   inflating: __MACOSX/faces_dataset_small/._01836.png
#   inflating: faces_dataset_small/01188.png
#   inflating: __MACOSX/faces_dataset_small/._01188.png
#   inflating: faces_dataset_small/00296.png
#   inflating: __MACOSX/faces_dataset_small/._00296.png
#   inflating: faces_dataset_small/02481.png
#   inflating: __MACOSX/faces_dataset_small/._02481.png
#   inflating: faces_dataset_small/03947.png
#   inflating: __MACOSX/faces_dataset_small/._03947.png
#   inflating: faces_dataset_small/02495.png
#   inflating: __MACOSX/faces_dataset_small/._02495.png
#   inflating: faces_dataset_small/03953.png
#   inflating: __MACOSX/faces_dataset_small/._03953.png
#   inflating: faces_dataset_small/00282.png
#   inflating: __MACOSX/faces_dataset_small/._00282.png
#   inflating: faces_dataset_small/01822.png
#   inflating: __MACOSX/faces_dataset_small/._01822.png
#   inflating: faces_dataset_small/04782.png
#   inflating: __MACOSX/faces_dataset_small/._04782.png
#   inflating: faces_dataset_small/04769.png
#   inflating: __MACOSX/faces_dataset_small/._04769.png
#   inflating: faces_dataset_small/02318.png
#   inflating: __MACOSX/faces_dataset_small/._02318.png
#   inflating: faces_dataset_small/01611.png
#   inflating: __MACOSX/faces_dataset_small/._01611.png
#   inflating: faces_dataset_small/00269.png
#   inflating: __MACOSX/faces_dataset_small/._00269.png
#   inflating: faces_dataset_small/01177.png
#   inflating: __MACOSX/faces_dataset_small/._01177.png
#   inflating: faces_dataset_small/03760.png
#   inflating: __MACOSX/faces_dataset_small/._03760.png
#   inflating: faces_dataset_small/03774.png
#   inflating: __MACOSX/faces_dataset_small/._03774.png
#   inflating: faces_dataset_small/01605.png
#   inflating: __MACOSX/faces_dataset_small/._01605.png
#   inflating: faces_dataset_small/00533.png
#   inflating: __MACOSX/faces_dataset_small/._00533.png
#   inflating: faces_dataset_small/04755.png
#   inflating: __MACOSX/faces_dataset_small/._04755.png
#   inflating: faces_dataset_small/02324.png
#   inflating: __MACOSX/faces_dataset_small/._02324.png
#   inflating: faces_dataset_small/02442.png
#   inflating: __MACOSX/faces_dataset_small/._02442.png
#   inflating: faces_dataset_small/03984.png
#   inflating: __MACOSX/faces_dataset_small/._03984.png
#   inflating: faces_dataset_small/00255.png
#   inflating: __MACOSX/faces_dataset_small/._00255.png
#   inflating: faces_dataset_small/00241.png
#   inflating: __MACOSX/faces_dataset_small/._00241.png
#   inflating: faces_dataset_small/03990.png
#   inflating: __MACOSX/faces_dataset_small/._03990.png
#   inflating: faces_dataset_small/04741.png
#   inflating: __MACOSX/faces_dataset_small/._04741.png
#   inflating: faces_dataset_small/02330.png
#   inflating: __MACOSX/faces_dataset_small/._02330.png
#   inflating: faces_dataset_small/04999.png
#   inflating: __MACOSX/faces_dataset_small/._04999.png
#   inflating: faces_dataset_small/01639.png
#   inflating: __MACOSX/faces_dataset_small/._01639.png
#   inflating: faces_dataset_small/00527.png
#   inflating: __MACOSX/faces_dataset_small/._00527.png
#   inflating: faces_dataset_small/03991.png
#   inflating: __MACOSX/faces_dataset_small/._03991.png
#   inflating: faces_dataset_small/00240.png
#   inflating: __MACOSX/faces_dataset_small/._00240.png
#   inflating: faces_dataset_small/00526.png
#   inflating: __MACOSX/faces_dataset_small/._00526.png
#   inflating: faces_dataset_small/01638.png
#   inflating: __MACOSX/faces_dataset_small/._01638.png
#   inflating: faces_dataset_small/04998.png
#   inflating: __MACOSX/faces_dataset_small/._04998.png
#   inflating: faces_dataset_small/02331.png
#   inflating: __MACOSX/faces_dataset_small/._02331.png
#   inflating: faces_dataset_small/04740.png
#   inflating: __MACOSX/faces_dataset_small/._04740.png
#   inflating: faces_dataset_small/02325.png
#   inflating: __MACOSX/faces_dataset_small/._02325.png
#   inflating: faces_dataset_small/04754.png
#   inflating: __MACOSX/faces_dataset_small/._04754.png
#   inflating: faces_dataset_small/00532.png
#   inflating: __MACOSX/faces_dataset_small/._00532.png
#   inflating: faces_dataset_small/03985.png
#   inflating: __MACOSX/faces_dataset_small/._03985.png
#   inflating: faces_dataset_small/02443.png
#   inflating: __MACOSX/faces_dataset_small/._02443.png
#   inflating: faces_dataset_small/03775.png
#   inflating: __MACOSX/faces_dataset_small/._03775.png
#   inflating: faces_dataset_small/01604.png
#   inflating: __MACOSX/faces_dataset_small/._01604.png
#   inflating: faces_dataset_small/01610.png
#   inflating: __MACOSX/faces_dataset_small/._01610.png
#   inflating: faces_dataset_small/02319.png
#   inflating: __MACOSX/faces_dataset_small/._02319.png
#   inflating: faces_dataset_small/04768.png
#   inflating: __MACOSX/faces_dataset_small/._04768.png
#   inflating: faces_dataset_small/03761.png
#   inflating: __MACOSX/faces_dataset_small/._03761.png
#   inflating: faces_dataset_small/01176.png
#   inflating: __MACOSX/faces_dataset_small/._01176.png
#   inflating: faces_dataset_small/00268.png
#   inflating: __MACOSX/faces_dataset_small/._00268.png
#   inflating: faces_dataset_small/00283.png
#   inflating: __MACOSX/faces_dataset_small/._00283.png
#   inflating: faces_dataset_small/03952.png
#   inflating: __MACOSX/faces_dataset_small/._03952.png
#   inflating: faces_dataset_small/02494.png
#   inflating: __MACOSX/faces_dataset_small/._02494.png
#   inflating: faces_dataset_small/04783.png
#   inflating: __MACOSX/faces_dataset_small/._04783.png
#   inflating: faces_dataset_small/01823.png
#   inflating: __MACOSX/faces_dataset_small/._01823.png
#   inflating: faces_dataset_small/01837.png
#   inflating: __MACOSX/faces_dataset_small/._01837.png
#   inflating: faces_dataset_small/04797.png
#   inflating: __MACOSX/faces_dataset_small/._04797.png
#   inflating: faces_dataset_small/03946.png
#   inflating: __MACOSX/faces_dataset_small/._03946.png
#   inflating: faces_dataset_small/02480.png
#   inflating: __MACOSX/faces_dataset_small/._02480.png
#   inflating: faces_dataset_small/00297.png
#   inflating: __MACOSX/faces_dataset_small/._00297.png
#   inflating: faces_dataset_small/01189.png
#   inflating: __MACOSX/faces_dataset_small/._01189.png
#   inflating: faces_dataset_small/04967.png
#   inflating: __MACOSX/faces_dataset_small/._04967.png
#   inflating: faces_dataset_small/04973.png
#   inflating: __MACOSX/faces_dataset_small/._04973.png
#   inflating: faces_dataset_small/04542.png
#   inflating: __MACOSX/faces_dataset_small/._04542.png
#   inflating: faces_dataset_small/02133.png
#   inflating: __MACOSX/faces_dataset_small/._02133.png
#   inflating: faces_dataset_small/00724.png
#   inflating: __MACOSX/faces_dataset_small/._00724.png
#   inflating: faces_dataset_small/02655.png
#   inflating: __MACOSX/faces_dataset_small/._02655.png
#   inflating: faces_dataset_small/04224.png
#   inflating: __MACOSX/faces_dataset_small/._04224.png
#   inflating: faces_dataset_small/02641.png
#   inflating: __MACOSX/faces_dataset_small/._02641.png
#   inflating: faces_dataset_small/02899.png
#   inflating: __MACOSX/faces_dataset_small/._02899.png
#   inflating: faces_dataset_small/01348.png
#   inflating: __MACOSX/faces_dataset_small/._01348.png
#   inflating: faces_dataset_small/04556.png
#   inflating: __MACOSX/faces_dataset_small/._04556.png
#   inflating: faces_dataset_small/01406.png
#   inflating: __MACOSX/faces_dataset_small/._01406.png
#   inflating: faces_dataset_small/00718.png
#   inflating: __MACOSX/faces_dataset_small/._00718.png
#   inflating: faces_dataset_small/02669.png
#   inflating: __MACOSX/faces_dataset_small/._02669.png
#   inflating: faces_dataset_small/04218.png
#   inflating: __MACOSX/faces_dataset_small/._04218.png
#   inflating: faces_dataset_small/01360.png
#   inflating: __MACOSX/faces_dataset_small/._01360.png
#   inflating: faces_dataset_small/01374.png
#   inflating: __MACOSX/faces_dataset_small/._01374.png
#   inflating: faces_dataset_small/03563.png
#   inflating: __MACOSX/faces_dataset_small/._03563.png
#   inflating: faces_dataset_small/01412.png
#   inflating: __MACOSX/faces_dataset_small/._01412.png
#   inflating: faces_dataset_small/03588.png
#   inflating: __MACOSX/faces_dataset_small/._03588.png
#   inflating: faces_dataset_small/02696.png
#   inflating: __MACOSX/faces_dataset_small/._02696.png
#   inflating: faces_dataset_small/02682.png
#   inflating: __MACOSX/faces_dataset_small/._02682.png
#   inflating: faces_dataset_small/00903.png
#   inflating: __MACOSX/faces_dataset_small/._00903.png
#   inflating: faces_dataset_small/02872.png
#   inflating: __MACOSX/faces_dataset_small/._02872.png
#   inflating: faces_dataset_small/02866.png
#   inflating: __MACOSX/faces_dataset_small/._02866.png
#   inflating: faces_dataset_small/00917.png
#   inflating: __MACOSX/faces_dataset_small/._00917.png
#   inflating: faces_dataset_small/04436.png
#   inflating: __MACOSX/faces_dataset_small/._04436.png
#   inflating: faces_dataset_small/03359.png
#   inflating: __MACOSX/faces_dataset_small/._03359.png
#   inflating: faces_dataset_small/00888.png
#   inflating: __MACOSX/faces_dataset_small/._00888.png
#   inflating: faces_dataset_small/01228.png
#   inflating: __MACOSX/faces_dataset_small/._01228.png
#   inflating: faces_dataset_small/04344.png
#   inflating: __MACOSX/faces_dataset_small/._04344.png
#   inflating: faces_dataset_small/02735.png
#   inflating: __MACOSX/faces_dataset_small/._02735.png
#   inflating: faces_dataset_small/04422.png
#   inflating: __MACOSX/faces_dataset_small/._04422.png
#   inflating: faces_dataset_small/01572.png
#   inflating: __MACOSX/faces_dataset_small/._01572.png
#   inflating: faces_dataset_small/03365.png
#   inflating: __MACOSX/faces_dataset_small/._03365.png
#   inflating: faces_dataset_small/03403.png
#   inflating: __MACOSX/faces_dataset_small/._03403.png
#   inflating: faces_dataset_small/01214.png
#   inflating: __MACOSX/faces_dataset_small/._01214.png
#   inflating: faces_dataset_small/03417.png
#   inflating: __MACOSX/faces_dataset_small/._03417.png
#   inflating: faces_dataset_small/04378.png
#   inflating: __MACOSX/faces_dataset_small/._04378.png
#   inflating: faces_dataset_small/03371.png
#   inflating: __MACOSX/faces_dataset_small/._03371.png
#   inflating: faces_dataset_small/00678.png
#   inflating: __MACOSX/faces_dataset_small/._00678.png
#   inflating: faces_dataset_small/01566.png
#   inflating: __MACOSX/faces_dataset_small/._01566.png
#   inflating: faces_dataset_small/00693.png
#   inflating: __MACOSX/faces_dataset_small/._00693.png
#   inflating: faces_dataset_small/04393.png
#   inflating: __MACOSX/faces_dataset_small/._04393.png
#   inflating: faces_dataset_small/04387.png
#   inflating: __MACOSX/faces_dataset_small/._04387.png
#   inflating: faces_dataset_small/01599.png
#   inflating: __MACOSX/faces_dataset_small/._01599.png
#   inflating: faces_dataset_small/00687.png
#   inflating: __MACOSX/faces_dataset_small/._00687.png
#   inflating: faces_dataset_small/00877.png
#   inflating: __MACOSX/faces_dataset_small/._00877.png
#   inflating: faces_dataset_small/02906.png
#   inflating: __MACOSX/faces_dataset_small/._02906.png
#   inflating: faces_dataset_small/02912.png
#   inflating: __MACOSX/faces_dataset_small/._02912.png
#   inflating: faces_dataset_small/00863.png
#   inflating: __MACOSX/faces_dataset_small/._00863.png
#   inflating: faces_dataset_small/02523.png
#   inflating: __MACOSX/faces_dataset_small/._02523.png
#   inflating: faces_dataset_small/01994.png
#   inflating: __MACOSX/faces_dataset_small/._01994.png
#   inflating: faces_dataset_small/00452.png
#   inflating: __MACOSX/faces_dataset_small/._00452.png
#   inflating: faces_dataset_small/04634.png
#   inflating: __MACOSX/faces_dataset_small/._04634.png
#   inflating: faces_dataset_small/02245.png
#   inflating: __MACOSX/faces_dataset_small/._02245.png
#   inflating: faces_dataset_small/04620.png
#   inflating: __MACOSX/faces_dataset_small/._04620.png
#   inflating: faces_dataset_small/02251.png
#   inflating: __MACOSX/faces_dataset_small/._02251.png
#   inflating: faces_dataset_small/01758.png
#   inflating: __MACOSX/faces_dataset_small/._01758.png
#   inflating: faces_dataset_small/01980.png
#   inflating: __MACOSX/faces_dataset_small/._01980.png
#   inflating: faces_dataset_small/03629.png
#   inflating: __MACOSX/faces_dataset_small/._03629.png
#   inflating: faces_dataset_small/03601.png
#   inflating: __MACOSX/faces_dataset_small/._03601.png
#   inflating: faces_dataset_small/04608.png
#   inflating: __MACOSX/faces_dataset_small/._04608.png
#   inflating: faces_dataset_small/02279.png
#   inflating: __MACOSX/faces_dataset_small/._02279.png
#   inflating: faces_dataset_small/01770.png
#   inflating: __MACOSX/faces_dataset_small/._01770.png
#   inflating: faces_dataset_small/01764.png
#   inflating: __MACOSX/faces_dataset_small/._01764.png
#   inflating: faces_dataset_small/03615.png
#   inflating: __MACOSX/faces_dataset_small/._03615.png
#   inflating: faces_dataset_small/04191.png
#   inflating: __MACOSX/faces_dataset_small/._04191.png
#   inflating: faces_dataset_small/03826.png
#   inflating: __MACOSX/faces_dataset_small/._03826.png
#   inflating: faces_dataset_small/02286.png
#   inflating: __MACOSX/faces_dataset_small/._02286.png
#   inflating: faces_dataset_small/01957.png
#   inflating: __MACOSX/faces_dataset_small/._01957.png
#   inflating: faces_dataset_small/00491.png
#   inflating: __MACOSX/faces_dataset_small/._00491.png
#   inflating: faces_dataset_small/01943.png
#   inflating: __MACOSX/faces_dataset_small/._01943.png
#   inflating: faces_dataset_small/00485.png
#   inflating: __MACOSX/faces_dataset_small/._00485.png
#   inflating: faces_dataset_small/02292.png
#   inflating: __MACOSX/faces_dataset_small/._02292.png
#   inflating: faces_dataset_small/04185.png
#   inflating: __MACOSX/faces_dataset_small/._04185.png
#   inflating: faces_dataset_small/03832.png
#   inflating: __MACOSX/faces_dataset_small/._03832.png
#   inflating: faces_dataset_small/04813.png
#   inflating: __MACOSX/faces_dataset_small/._04813.png
#   inflating: faces_dataset_small/04807.png
#   inflating: __MACOSX/faces_dataset_small/._04807.png
#   inflating: faces_dataset_small/01924.png
#   inflating: __MACOSX/faces_dataset_small/._01924.png
#   inflating: faces_dataset_small/04684.png
#   inflating: __MACOSX/faces_dataset_small/._04684.png
#   inflating: faces_dataset_small/03855.png
#   inflating: __MACOSX/faces_dataset_small/._03855.png
#   inflating: faces_dataset_small/03841.png
#   inflating: __MACOSX/faces_dataset_small/._03841.png
#   inflating: faces_dataset_small/04690.png
#   inflating: __MACOSX/faces_dataset_small/._04690.png
#   inflating: faces_dataset_small/04848.png
#   inflating: __MACOSX/faces_dataset_small/._04848.png
#   inflating: faces_dataset_small/01930.png
#   inflating: __MACOSX/faces_dataset_small/._01930.png
#   inflating: faces_dataset_small/04860.png
#   inflating: __MACOSX/faces_dataset_small/._04860.png
#   inflating: faces_dataset_small/01918.png
#   inflating: __MACOSX/faces_dataset_small/._01918.png
#   inflating: faces_dataset_small/03869.png
#   inflating: __MACOSX/faces_dataset_small/._03869.png
#   inflating: faces_dataset_small/04874.png
#   inflating: __MACOSX/faces_dataset_small/._04874.png
#   inflating: faces_dataset_small/02236.png
#   inflating: __MACOSX/faces_dataset_small/._02236.png
#   inflating: faces_dataset_small/04647.png
#   inflating: __MACOSX/faces_dataset_small/._04647.png
#   inflating: faces_dataset_small/00421.png
#   inflating: __MACOSX/faces_dataset_small/._00421.png
#   inflating: faces_dataset_small/03896.png
#   inflating: __MACOSX/faces_dataset_small/._03896.png
#   inflating: faces_dataset_small/03882.png
#   inflating: __MACOSX/faces_dataset_small/._03882.png
#   inflating: faces_dataset_small/00353.png
#   inflating: __MACOSX/faces_dataset_small/._00353.png
#   inflating: faces_dataset_small/02222.png
#   inflating: __MACOSX/faces_dataset_small/._02222.png
#   inflating: faces_dataset_small/04653.png
#   inflating: __MACOSX/faces_dataset_small/._04653.png
#   inflating: faces_dataset_small/01703.png
#   inflating: __MACOSX/faces_dataset_small/._01703.png
#   inflating: faces_dataset_small/03672.png
#   inflating: __MACOSX/faces_dataset_small/._03672.png
#   inflating: faces_dataset_small/03666.png
#   inflating: __MACOSX/faces_dataset_small/._03666.png
#   inflating: faces_dataset_small/02578.png
#   inflating: __MACOSX/faces_dataset_small/._02578.png
#   inflating: faces_dataset_small/00409.png
#   inflating: __MACOSX/faces_dataset_small/._00409.png
#   inflating: faces_dataset_small/01717.png
#   inflating: __MACOSX/faces_dataset_small/._01717.png
#   inflating: faces_dataset_small/01298.png
#   inflating: __MACOSX/faces_dataset_small/._01298.png
#   inflating: faces_dataset_small/02949.png
#   inflating: __MACOSX/faces_dataset_small/._02949.png
#   inflating: faces_dataset_small/02791.png
#   inflating: __MACOSX/faces_dataset_small/._02791.png
#   inflating: faces_dataset_small/04486.png
#   inflating: __MACOSX/faces_dataset_small/._04486.png
#   inflating: faces_dataset_small/00838.png
#   inflating: __MACOSX/faces_dataset_small/._00838.png
#   inflating: faces_dataset_small/04492.png
#   inflating: __MACOSX/faces_dataset_small/._04492.png
#   inflating: faces_dataset_small/02785.png
#   inflating: __MACOSX/faces_dataset_small/._02785.png
#   inflating: faces_dataset_small/02975.png
#   inflating: __MACOSX/faces_dataset_small/._02975.png
#   inflating: faces_dataset_small/00804.png
#   inflating: __MACOSX/faces_dataset_small/._00804.png
#   inflating: faces_dataset_small/00810.png
#   inflating: __MACOSX/faces_dataset_small/._00810.png
#   inflating: faces_dataset_small/02961.png
#   inflating: __MACOSX/faces_dataset_small/._02961.png
#   inflating: faces_dataset_small/02752.png
#   inflating: __MACOSX/faces_dataset_small/._02752.png
#   inflating: faces_dataset_small/04323.png
#   inflating: __MACOSX/faces_dataset_small/._04323.png
#   inflating: faces_dataset_small/00623.png
#   inflating: __MACOSX/faces_dataset_small/._00623.png
#   inflating: faces_dataset_small/04445.png
#   inflating: __MACOSX/faces_dataset_small/._04445.png
#   inflating: faces_dataset_small/01529.png
#   inflating: __MACOSX/faces_dataset_small/._01529.png
#   inflating: faces_dataset_small/02746.png
#   inflating: __MACOSX/faces_dataset_small/._02746.png
#   inflating: faces_dataset_small/03458.png
#   inflating: __MACOSX/faces_dataset_small/._03458.png
#   inflating: faces_dataset_small/04337.png
#   inflating: __MACOSX/faces_dataset_small/._04337.png
#   inflating: faces_dataset_small/01267.png
#   inflating: __MACOSX/faces_dataset_small/._01267.png
#   inflating: faces_dataset_small/03470.png
#   inflating: __MACOSX/faces_dataset_small/._03470.png
#   inflating: faces_dataset_small/04479.png
#   inflating: __MACOSX/faces_dataset_small/._04479.png
#   inflating: faces_dataset_small/03316.png
#   inflating: __MACOSX/faces_dataset_small/._03316.png
#   inflating: faces_dataset_small/03302.png
#   inflating: __MACOSX/faces_dataset_small/._03302.png
#   inflating: faces_dataset_small/03464.png
#   inflating: __MACOSX/faces_dataset_small/._03464.png
#   inflating: faces_dataset_small/01273.png
#   inflating: __MACOSX/faces_dataset_small/._01273.png
#   inflating: faces_dataset_small/04294.png
#   inflating: __MACOSX/faces_dataset_small/._04294.png
#   inflating: faces_dataset_small/02183.png
#   inflating: __MACOSX/faces_dataset_small/._02183.png
#   inflating: faces_dataset_small/00794.png
#   inflating: __MACOSX/faces_dataset_small/._00794.png
#   inflating: faces_dataset_small/00958.png
#   inflating: __MACOSX/faces_dataset_small/._00958.png
#   inflating: faces_dataset_small/00780.png
#   inflating: __MACOSX/faces_dataset_small/._00780.png
#   inflating: faces_dataset_small/02197.png
#   inflating: __MACOSX/faces_dataset_small/._02197.png
#   inflating: faces_dataset_small/02829.png
#   inflating: __MACOSX/faces_dataset_small/._02829.png
#   inflating: faces_dataset_small/02801.png
#   inflating: __MACOSX/faces_dataset_small/._02801.png
#   inflating: faces_dataset_small/00970.png
#   inflating: __MACOSX/faces_dataset_small/._00970.png
#   inflating: faces_dataset_small/00964.png
#   inflating: __MACOSX/faces_dataset_small/._00964.png
#   inflating: faces_dataset_small/02815.png
#   inflating: __MACOSX/faces_dataset_small/._02815.png
#   inflating: faces_dataset_small/04257.png
#   inflating: __MACOSX/faces_dataset_small/._04257.png
#   inflating: faces_dataset_small/00757.png
#   inflating: __MACOSX/faces_dataset_small/._00757.png
#   inflating: faces_dataset_small/01449.png
#   inflating: __MACOSX/faces_dataset_small/._01449.png
#   inflating: faces_dataset_small/02140.png
#   inflating: __MACOSX/faces_dataset_small/._02140.png
#   inflating: faces_dataset_small/04531.png
#   inflating: __MACOSX/faces_dataset_small/._04531.png
#   inflating: faces_dataset_small/04525.png
#   inflating: __MACOSX/faces_dataset_small/._04525.png
#   inflating: faces_dataset_small/00743.png
#   inflating: __MACOSX/faces_dataset_small/._00743.png
#   inflating: faces_dataset_small/01313.png
#   inflating: __MACOSX/faces_dataset_small/._01313.png
#   inflating: faces_dataset_small/03504.png
#   inflating: __MACOSX/faces_dataset_small/._03504.png
#   inflating: faces_dataset_small/01475.png
#   inflating: __MACOSX/faces_dataset_small/._01475.png
#   inflating: faces_dataset_small/01461.png
#   inflating: __MACOSX/faces_dataset_small/._01461.png
#   inflating: faces_dataset_small/02168.png
#   inflating: __MACOSX/faces_dataset_small/._02168.png
#   inflating: faces_dataset_small/03510.png
#   inflating: __MACOSX/faces_dataset_small/._03510.png
#   inflating: faces_dataset_small/01307.png
#   inflating: __MACOSX/faces_dataset_small/._01307.png
#   inflating: faces_dataset_small/01850.png
#   inflating: __MACOSX/faces_dataset_small/._01850.png
#   inflating: faces_dataset_small/01688.png
#   inflating: __MACOSX/faces_dataset_small/._01688.png
#   inflating: faces_dataset_small/04928.png
#   inflating: __MACOSX/faces_dataset_small/._04928.png
#   inflating: faces_dataset_small/03921.png
#   inflating: __MACOSX/faces_dataset_small/._03921.png
#   inflating: faces_dataset_small/03935.png
#   inflating: __MACOSX/faces_dataset_small/._03935.png
#   inflating: faces_dataset_small/02395.png
#   inflating: __MACOSX/faces_dataset_small/._02395.png
#   inflating: faces_dataset_small/01844.png
#   inflating: __MACOSX/faces_dataset_small/._01844.png
#   inflating: faces_dataset_small/04914.png
#   inflating: __MACOSX/faces_dataset_small/._04914.png
#   inflating: faces_dataset_small/03909.png
#   inflating: __MACOSX/faces_dataset_small/._03909.png
#   inflating: faces_dataset_small/01878.png
#   inflating: __MACOSX/faces_dataset_small/._01878.png
#   inflating: faces_dataset_small/04900.png
#   inflating: __MACOSX/faces_dataset_small/._04900.png
#   inflating: faces_dataset_small/04733.png
#   inflating: __MACOSX/faces_dataset_small/._04733.png
#   inflating: faces_dataset_small/02342.png
#   inflating: __MACOSX/faces_dataset_small/._02342.png
#   inflating: faces_dataset_small/00555.png
#   inflating: __MACOSX/faces_dataset_small/._00555.png
#   inflating: faces_dataset_small/01893.png
#   inflating: __MACOSX/faces_dataset_small/._01893.png
#   inflating: faces_dataset_small/02424.png
#   inflating: __MACOSX/faces_dataset_small/._02424.png
#   inflating: faces_dataset_small/02430.png
#   inflating: __MACOSX/faces_dataset_small/._02430.png
#   inflating: faces_dataset_small/00541.png
#   inflating: __MACOSX/faces_dataset_small/._00541.png
#   inflating: faces_dataset_small/01887.png
#   inflating: __MACOSX/faces_dataset_small/._01887.png
#   inflating: faces_dataset_small/04727.png
#   inflating: __MACOSX/faces_dataset_small/._04727.png
#   inflating: faces_dataset_small/02356.png
#   inflating: __MACOSX/faces_dataset_small/._02356.png
#   inflating: faces_dataset_small/01677.png
#   inflating: __MACOSX/faces_dataset_small/._01677.png
#   inflating: faces_dataset_small/00569.png
#   inflating: __MACOSX/faces_dataset_small/._00569.png
#   inflating: faces_dataset_small/02418.png
#   inflating: __MACOSX/faces_dataset_small/._02418.png
#   inflating: faces_dataset_small/03706.png
#   inflating: __MACOSX/faces_dataset_small/._03706.png
#   inflating: faces_dataset_small/03712.png
#   inflating: __MACOSX/faces_dataset_small/._03712.png
#   inflating: faces_dataset_small/03713.png
#   inflating: __MACOSX/faces_dataset_small/._03713.png
#   inflating: faces_dataset_small/00568.png
#   inflating: __MACOSX/faces_dataset_small/._00568.png
#   inflating: faces_dataset_small/01676.png
#   inflating: __MACOSX/faces_dataset_small/._01676.png
#   inflating: faces_dataset_small/03707.png
#   inflating: __MACOSX/faces_dataset_small/._03707.png
#   inflating: faces_dataset_small/02419.png
#   inflating: __MACOSX/faces_dataset_small/._02419.png
#   inflating: faces_dataset_small/02431.png
#   inflating: __MACOSX/faces_dataset_small/._02431.png
#   inflating: faces_dataset_small/02357.png
#   inflating: __MACOSX/faces_dataset_small/._02357.png
#   inflating: faces_dataset_small/04726.png
#   inflating: __MACOSX/faces_dataset_small/._04726.png
#   inflating: faces_dataset_small/01886.png
#   inflating: __MACOSX/faces_dataset_small/._01886.png
#   inflating: faces_dataset_small/00540.png
#   inflating: __MACOSX/faces_dataset_small/._00540.png
#   inflating: faces_dataset_small/01892.png
#   inflating: __MACOSX/faces_dataset_small/._01892.png
#   inflating: faces_dataset_small/00554.png
#   inflating: __MACOSX/faces_dataset_small/._00554.png
#   inflating: faces_dataset_small/02343.png
#   inflating: __MACOSX/faces_dataset_small/._02343.png
#   inflating: faces_dataset_small/04732.png
#   inflating: __MACOSX/faces_dataset_small/._04732.png
#   inflating: faces_dataset_small/02425.png
#   inflating: __MACOSX/faces_dataset_small/._02425.png
#   inflating: faces_dataset_small/03908.png
#   inflating: __MACOSX/faces_dataset_small/._03908.png
#   inflating: faces_dataset_small/04901.png
#   inflating: __MACOSX/faces_dataset_small/._04901.png
#   inflating: faces_dataset_small/01879.png
#   inflating: __MACOSX/faces_dataset_small/._01879.png
#   inflating: faces_dataset_small/04915.png
#   inflating: __MACOSX/faces_dataset_small/._04915.png
#   inflating: faces_dataset_small/03934.png
#   inflating: __MACOSX/faces_dataset_small/._03934.png
#   inflating: faces_dataset_small/01845.png
#   inflating: __MACOSX/faces_dataset_small/._01845.png
#   inflating: faces_dataset_small/02394.png
#   inflating: __MACOSX/faces_dataset_small/._02394.png
#   inflating: faces_dataset_small/04929.png
#   inflating: __MACOSX/faces_dataset_small/._04929.png
#   inflating: faces_dataset_small/01689.png
#   inflating: __MACOSX/faces_dataset_small/._01689.png
#   inflating: faces_dataset_small/01851.png
#   inflating: __MACOSX/faces_dataset_small/._01851.png
#   inflating: faces_dataset_small/03920.png
#   inflating: __MACOSX/faces_dataset_small/._03920.png
#   inflating: faces_dataset_small/02169.png
#   inflating: __MACOSX/faces_dataset_small/._02169.png
#   inflating: faces_dataset_small/01460.png
#   inflating: __MACOSX/faces_dataset_small/._01460.png
#   inflating: faces_dataset_small/01306.png
#   inflating: __MACOSX/faces_dataset_small/._01306.png
#   inflating: faces_dataset_small/03511.png
#   inflating: __MACOSX/faces_dataset_small/._03511.png
#   inflating: faces_dataset_small/03505.png
#   inflating: __MACOSX/faces_dataset_small/._03505.png
#   inflating: faces_dataset_small/01312.png
#   inflating: __MACOSX/faces_dataset_small/._01312.png
#   inflating: faces_dataset_small/01474.png
#   inflating: __MACOSX/faces_dataset_small/._01474.png
#   inflating: faces_dataset_small/00742.png
#   inflating: __MACOSX/faces_dataset_small/._00742.png
#   inflating: faces_dataset_small/04256.png
#   inflating: __MACOSX/faces_dataset_small/._04256.png
#   inflating: faces_dataset_small/04530.png
#   inflating: __MACOSX/faces_dataset_small/._04530.png
#   inflating: faces_dataset_small/02141.png
#   inflating: __MACOSX/faces_dataset_small/._02141.png
#   inflating: faces_dataset_small/01448.png
#   inflating: __MACOSX/faces_dataset_small/._01448.png
#   inflating: faces_dataset_small/00756.png
#   inflating: __MACOSX/faces_dataset_small/._00756.png
#   inflating: faces_dataset_small/00965.png
#   inflating: __MACOSX/faces_dataset_small/._00965.png
#   inflating: faces_dataset_small/02814.png
#   inflating: __MACOSX/faces_dataset_small/._02814.png
#   inflating: faces_dataset_small/02800.png
#   inflating: __MACOSX/faces_dataset_small/._02800.png
#   inflating: faces_dataset_small/00971.png
#   inflating: __MACOSX/faces_dataset_small/._00971.png
#   inflating: faces_dataset_small/02196.png
#   inflating: __MACOSX/faces_dataset_small/._02196.png
#   inflating: faces_dataset_small/00781.png
#   inflating: __MACOSX/faces_dataset_small/._00781.png
#   inflating: faces_dataset_small/00959.png
#   inflating: __MACOSX/faces_dataset_small/._00959.png
#   inflating: faces_dataset_small/04281.png
#   inflating: __MACOSX/faces_dataset_small/._04281.png
#   inflating: faces_dataset_small/02828.png
#   inflating: __MACOSX/faces_dataset_small/._02828.png
#   inflating: faces_dataset_small/04295.png
#   inflating: __MACOSX/faces_dataset_small/._04295.png
#   inflating: faces_dataset_small/00795.png
#   inflating: __MACOSX/faces_dataset_small/._00795.png
#   inflating: faces_dataset_small/02182.png
#   inflating: __MACOSX/faces_dataset_small/._02182.png
#   inflating: faces_dataset_small/03303.png
#   inflating: __MACOSX/faces_dataset_small/._03303.png
#   inflating: faces_dataset_small/01272.png
#   inflating: __MACOSX/faces_dataset_small/._01272.png
#   inflating: faces_dataset_small/03465.png
#   inflating: __MACOSX/faces_dataset_small/._03465.png
#   inflating: faces_dataset_small/03471.png
#   inflating: __MACOSX/faces_dataset_small/._03471.png
#   inflating: faces_dataset_small/01266.png
#   inflating: __MACOSX/faces_dataset_small/._01266.png
#   inflating: faces_dataset_small/03317.png
#   inflating: __MACOSX/faces_dataset_small/._03317.png
#   inflating: faces_dataset_small/04478.png
#   inflating: __MACOSX/faces_dataset_small/._04478.png
#   inflating: faces_dataset_small/01528.png
#   inflating: __MACOSX/faces_dataset_small/._01528.png
#   inflating: faces_dataset_small/04336.png
#   inflating: __MACOSX/faces_dataset_small/._04336.png
#   inflating: faces_dataset_small/03459.png
#   inflating: __MACOSX/faces_dataset_small/._03459.png
#   inflating: faces_dataset_small/02747.png
#   inflating: __MACOSX/faces_dataset_small/._02747.png
#   inflating: faces_dataset_small/02753.png
#   inflating: __MACOSX/faces_dataset_small/._02753.png
#   inflating: faces_dataset_small/04444.png
#   inflating: __MACOSX/faces_dataset_small/._04444.png
#   inflating: faces_dataset_small/00622.png
#   inflating: __MACOSX/faces_dataset_small/._00622.png
#   inflating: faces_dataset_small/00811.png
#   inflating: __MACOSX/faces_dataset_small/._00811.png
#   inflating: faces_dataset_small/02960.png
#   inflating: __MACOSX/faces_dataset_small/._02960.png
#   inflating: faces_dataset_small/02974.png
#   inflating: __MACOSX/faces_dataset_small/._02974.png
#   inflating: faces_dataset_small/00805.png
#   inflating: __MACOSX/faces_dataset_small/._00805.png
#   inflating: faces_dataset_small/04493.png
#   inflating: __MACOSX/faces_dataset_small/._04493.png
#   inflating: faces_dataset_small/02784.png
#   inflating: __MACOSX/faces_dataset_small/._02784.png
#   inflating: faces_dataset_small/02790.png
#   inflating: __MACOSX/faces_dataset_small/._02790.png
#   inflating: faces_dataset_small/02948.png
#   inflating: __MACOSX/faces_dataset_small/._02948.png
#   inflating: faces_dataset_small/01299.png
#   inflating: __MACOSX/faces_dataset_small/._01299.png
#   inflating: faces_dataset_small/00839.png
#   inflating: __MACOSX/faces_dataset_small/._00839.png
#   inflating: faces_dataset_small/04487.png
#   inflating: __MACOSX/faces_dataset_small/._04487.png
#   inflating: faces_dataset_small/03667.png
#   inflating: __MACOSX/faces_dataset_small/._03667.png
#   inflating: faces_dataset_small/01716.png
#   inflating: __MACOSX/faces_dataset_small/._01716.png
#   inflating: faces_dataset_small/00408.png
#   inflating: __MACOSX/faces_dataset_small/._00408.png
#   inflating: faces_dataset_small/01702.png
#   inflating: __MACOSX/faces_dataset_small/._01702.png
#   inflating: faces_dataset_small/03673.png
#   inflating: __MACOSX/faces_dataset_small/._03673.png
#   inflating: faces_dataset_small/00352.png
#   inflating: __MACOSX/faces_dataset_small/._00352.png
#   inflating: faces_dataset_small/03883.png
#   inflating: __MACOSX/faces_dataset_small/._03883.png
#   inflating: faces_dataset_small/02223.png
#   inflating: __MACOSX/faces_dataset_small/._02223.png
#   inflating: faces_dataset_small/00420.png
#   inflating: __MACOSX/faces_dataset_small/._00420.png
#   inflating: faces_dataset_small/04646.png
#   inflating: __MACOSX/faces_dataset_small/._04646.png
#   inflating: faces_dataset_small/02237.png
#   inflating: __MACOSX/faces_dataset_small/._02237.png
#   inflating: faces_dataset_small/03897.png
#   inflating: __MACOSX/faces_dataset_small/._03897.png
#   inflating: faces_dataset_small/04875.png
#   inflating: __MACOSX/faces_dataset_small/._04875.png
#   inflating: faces_dataset_small/01919.png
#   inflating: __MACOSX/faces_dataset_small/._01919.png
#   inflating: faces_dataset_small/04861.png
#   inflating: __MACOSX/faces_dataset_small/._04861.png
#   inflating: faces_dataset_small/03868.png
#   inflating: __MACOSX/faces_dataset_small/._03868.png
#   inflating: faces_dataset_small/03840.png
#   inflating: __MACOSX/faces_dataset_small/._03840.png
#   inflating: faces_dataset_small/01931.png
#   inflating: __MACOSX/faces_dataset_small/._01931.png
#   inflating: faces_dataset_small/04849.png
#   inflating: __MACOSX/faces_dataset_small/._04849.png
#   inflating: faces_dataset_small/04691.png
#   inflating: __MACOSX/faces_dataset_small/._04691.png
#   inflating: faces_dataset_small/04685.png
#   inflating: __MACOSX/faces_dataset_small/._04685.png
#   inflating: faces_dataset_small/01925.png
#   inflating: __MACOSX/faces_dataset_small/._01925.png
#   inflating: faces_dataset_small/03854.png
#   inflating: __MACOSX/faces_dataset_small/._03854.png
#   inflating: faces_dataset_small/04693.png
#   inflating: __MACOSX/faces_dataset_small/._04693.png
#   inflating: faces_dataset_small/01933.png
#   inflating: __MACOSX/faces_dataset_small/._01933.png
#   inflating: faces_dataset_small/03842.png
#   inflating: __MACOSX/faces_dataset_small/._03842.png
#   inflating: faces_dataset_small/03856.png
#   inflating: __MACOSX/faces_dataset_small/._03856.png
#   inflating: faces_dataset_small/01927.png
#   inflating: __MACOSX/faces_dataset_small/._01927.png
#   inflating: faces_dataset_small/04687.png
#   inflating: __MACOSX/faces_dataset_small/._04687.png
#   inflating: faces_dataset_small/04877.png
#   inflating: __MACOSX/faces_dataset_small/._04877.png
#   inflating: faces_dataset_small/04863.png
#   inflating: __MACOSX/faces_dataset_small/._04863.png
#   inflating: faces_dataset_small/02221.png
#   inflating: __MACOSX/faces_dataset_small/._02221.png
#   inflating: faces_dataset_small/04888.png
#   inflating: __MACOSX/faces_dataset_small/._04888.png
#   inflating: faces_dataset_small/03659.png
#   inflating: __MACOSX/faces_dataset_small/._03659.png
#   inflating: faces_dataset_small/03881.png
#   inflating: __MACOSX/faces_dataset_small/._03881.png
#   inflating: faces_dataset_small/00350.png
#   inflating: __MACOSX/faces_dataset_small/._00350.png
#   inflating: faces_dataset_small/03895.png
#   inflating: __MACOSX/faces_dataset_small/._03895.png
#   inflating: faces_dataset_small/02235.png
#   inflating: __MACOSX/faces_dataset_small/._02235.png
#   inflating: faces_dataset_small/04644.png
#   inflating: __MACOSX/faces_dataset_small/._04644.png
#   inflating: faces_dataset_small/00422.png
#   inflating: __MACOSX/faces_dataset_small/._00422.png
#   inflating: faces_dataset_small/01714.png
#   inflating: __MACOSX/faces_dataset_small/._01714.png
#   inflating: faces_dataset_small/03665.png
#   inflating: __MACOSX/faces_dataset_small/._03665.png
#   inflating: faces_dataset_small/03671.png
#   inflating: __MACOSX/faces_dataset_small/._03671.png
#   inflating: faces_dataset_small/01700.png
#   inflating: __MACOSX/faces_dataset_small/._01700.png
#   inflating: faces_dataset_small/02209.png
#   inflating: __MACOSX/faces_dataset_small/._02209.png
#   inflating: faces_dataset_small/04678.png
#   inflating: __MACOSX/faces_dataset_small/._04678.png
#   inflating: faces_dataset_small/02786.png
#   inflating: __MACOSX/faces_dataset_small/._02786.png
#   inflating: faces_dataset_small/04491.png
#   inflating: __MACOSX/faces_dataset_small/._04491.png
#   inflating: faces_dataset_small/04485.png
#   inflating: __MACOSX/faces_dataset_small/._04485.png
#   inflating: faces_dataset_small/02792.png
#   inflating: __MACOSX/faces_dataset_small/._02792.png
#   inflating: faces_dataset_small/02962.png
#   inflating: __MACOSX/faces_dataset_small/._02962.png
#   inflating: faces_dataset_small/00813.png
#   inflating: __MACOSX/faces_dataset_small/._00813.png
#   inflating: faces_dataset_small/00807.png
#   inflating: __MACOSX/faces_dataset_small/._00807.png
#   inflating: faces_dataset_small/02976.png
#   inflating: __MACOSX/faces_dataset_small/._02976.png
#   inflating: faces_dataset_small/02745.png
#   inflating: __MACOSX/faces_dataset_small/._02745.png
#   inflating: faces_dataset_small/04334.png
#   inflating: __MACOSX/faces_dataset_small/._04334.png
#   inflating: faces_dataset_small/00620.png
#   inflating: __MACOSX/faces_dataset_small/._00620.png
#   inflating: faces_dataset_small/04446.png
#   inflating: __MACOSX/faces_dataset_small/._04446.png
#   inflating: faces_dataset_small/02751.png
#   inflating: __MACOSX/faces_dataset_small/._02751.png
#   inflating: faces_dataset_small/02989.png
#   inflating: __MACOSX/faces_dataset_small/._02989.png
#   inflating: faces_dataset_small/02779.png
#   inflating: __MACOSX/faces_dataset_small/._02779.png
#   inflating: faces_dataset_small/03467.png
#   inflating: __MACOSX/faces_dataset_small/._03467.png
#   inflating: faces_dataset_small/01270.png
#   inflating: __MACOSX/faces_dataset_small/._01270.png
#   inflating: faces_dataset_small/00608.png
#   inflating: __MACOSX/faces_dataset_small/._00608.png
#   inflating: faces_dataset_small/03301.png
#   inflating: __MACOSX/faces_dataset_small/._03301.png
#   inflating: faces_dataset_small/03315.png
#   inflating: __MACOSX/faces_dataset_small/._03315.png
#   inflating: faces_dataset_small/01264.png
#   inflating: __MACOSX/faces_dataset_small/._01264.png
#   inflating: faces_dataset_small/03473.png
#   inflating: __MACOSX/faces_dataset_small/._03473.png
#   inflating: faces_dataset_small/04283.png
#   inflating: __MACOSX/faces_dataset_small/._04283.png
#   inflating: faces_dataset_small/00783.png
#   inflating: __MACOSX/faces_dataset_small/._00783.png
#   inflating: faces_dataset_small/02194.png
#   inflating: __MACOSX/faces_dataset_small/._02194.png
#   inflating: faces_dataset_small/02180.png
#   inflating: __MACOSX/faces_dataset_small/._02180.png
#   inflating: faces_dataset_small/01489.png
#   inflating: __MACOSX/faces_dataset_small/._01489.png
#   inflating: faces_dataset_small/00797.png
#   inflating: __MACOSX/faces_dataset_small/._00797.png
#   inflating: faces_dataset_small/04297.png
#   inflating: __MACOSX/faces_dataset_small/._04297.png
#   inflating: faces_dataset_small/02816.png
#   inflating: __MACOSX/faces_dataset_small/._02816.png
#   inflating: faces_dataset_small/00967.png
#   inflating: __MACOSX/faces_dataset_small/._00967.png
#   inflating: faces_dataset_small/00973.png
#   inflating: __MACOSX/faces_dataset_small/._00973.png
#   inflating: faces_dataset_small/02802.png
#   inflating: __MACOSX/faces_dataset_small/._02802.png
#   inflating: faces_dataset_small/04526.png
#   inflating: __MACOSX/faces_dataset_small/._04526.png
#   inflating: faces_dataset_small/00740.png
#   inflating: __MACOSX/faces_dataset_small/._00740.png
#   inflating: faces_dataset_small/00998.png
#   inflating: __MACOSX/faces_dataset_small/._00998.png
#   inflating: faces_dataset_small/00754.png
#   inflating: __MACOSX/faces_dataset_small/._00754.png
#   inflating: faces_dataset_small/02143.png
#   inflating: __MACOSX/faces_dataset_small/._02143.png
#   inflating: faces_dataset_small/04532.png
#   inflating: __MACOSX/faces_dataset_small/._04532.png
#   inflating: faces_dataset_small/04254.png
#   inflating: __MACOSX/faces_dataset_small/._04254.png
#   inflating: faces_dataset_small/03513.png
#   inflating: __MACOSX/faces_dataset_small/._03513.png
#   inflating: faces_dataset_small/01304.png
# ...
#   inflating: faces_dataset_small/01552.png
#   inflating: __MACOSX/faces_dataset_small/._01552.png
#   inflating: faces_dataset_small/00894.png
#   inflating: __MACOSX/faces_dataset_small/._00894.png
#   inflating: faces_dataset_small/03423.png
#   inflating: __MACOSX/faces_dataset_small/._03423.png
#   inflating: faces_dataset_small/01234.png
#   inflating: __MACOSX/faces_dataset_small/._01234.png
#   inflating: faces_dataset_small/00664.png
#   inflating: __MACOSX/faces_dataset_small/._00664.png
#   inflating: faces_dataset_small/00670.png
#   inflating: __MACOSX/faces_dataset_small/._00670.png
#   inflating: faces_dataset_small/02846.png
#   inflating: __MACOSX/faces_dataset_small/._02846.png
#   inflating: faces_dataset_small/01397.png
#   inflating: __MACOSX/faces_dataset_small/._01397.png
#   inflating: faces_dataset_small/00937.png
#   inflating: __MACOSX/faces_dataset_small/._00937.png
#   inflating: faces_dataset_small/00923.png
#   inflating: __MACOSX/faces_dataset_small/._00923.png
#   inflating: faces_dataset_small/01383.png
#   inflating: __MACOSX/faces_dataset_small/._01383.png
#   inflating: faces_dataset_small/03594.png
#   inflating: __MACOSX/faces_dataset_small/._03594.png
#   inflating: faces_dataset_small/02852.png
#   inflating: __MACOSX/faces_dataset_small/._02852.png
#   inflating: faces_dataset_small/01354.png
#   inflating: __MACOSX/faces_dataset_small/._01354.png
#   inflating: faces_dataset_small/02885.png
#   inflating: __MACOSX/faces_dataset_small/._02885.png
#   inflating: faces_dataset_small/00738.png
#   inflating: __MACOSX/faces_dataset_small/._00738.png
#   inflating: faces_dataset_small/03557.png
#   inflating: __MACOSX/faces_dataset_small/._03557.png
#   inflating: faces_dataset_small/02891.png
#   inflating: __MACOSX/faces_dataset_small/._02891.png
#   inflating: faces_dataset_small/02649.png
#   inflating: __MACOSX/faces_dataset_small/._02649.png
#   inflating: faces_dataset_small/04210.png
#   inflating: __MACOSX/faces_dataset_small/._04210.png
#   inflating: faces_dataset_small/02661.png
#   inflating: __MACOSX/faces_dataset_small/._02661.png
#   inflating: faces_dataset_small/01368.png
#   inflating: __MACOSX/faces_dataset_small/._01368.png
#   inflating: faces_dataset_small/00710.png
#   inflating: __MACOSX/faces_dataset_small/._00710.png
#   inflating: faces_dataset_small/04562.png
#   inflating: __MACOSX/faces_dataset_small/._04562.png
#   inflating: faces_dataset_small/00704.png
#   inflating: __MACOSX/faces_dataset_small/._00704.png
#   inflating: faces_dataset_small/04204.png
#   inflating: __MACOSX/faces_dataset_small/._04204.png
#   inflating: faces_dataset_small/02675.png
#   inflating: __MACOSX/faces_dataset_small/._02675.png
#   inflating: faces_dataset_small/04953.png
#   inflating: __MACOSX/faces_dataset_small/._04953.png
#   inflating: faces_dataset_small/01195.png
#   inflating: __MACOSX/faces_dataset_small/._01195.png
#   inflating: faces_dataset_small/03782.png
#   inflating: __MACOSX/faces_dataset_small/._03782.png
#   inflating: faces_dataset_small/03796.png
#   inflating: __MACOSX/faces_dataset_small/._03796.png
#   inflating: faces_dataset_small/02488.png
#   inflating: __MACOSX/faces_dataset_small/._02488.png
#   inflating: faces_dataset_small/01181.png
#   inflating: __MACOSX/faces_dataset_small/._01181.png
#   inflating: faces_dataset_small/04947.png
#   inflating: __MACOSX/faces_dataset_small/._04947.png
#   inflating: faces_dataset_small/01817.png
#   inflating: __MACOSX/faces_dataset_small/._01817.png
#   inflating: faces_dataset_small/03966.png
#   inflating: __MACOSX/faces_dataset_small/._03966.png
#   inflating: faces_dataset_small/03972.png
#   inflating: __MACOSX/faces_dataset_small/._03972.png
#   inflating: faces_dataset_small/01803.png
#   inflating: __MACOSX/faces_dataset_small/._01803.png
#   inflating: faces_dataset_small/01630.png
#   inflating: __MACOSX/faces_dataset_small/._01630.png
#   inflating: faces_dataset_small/04748.png
#   inflating: __MACOSX/faces_dataset_small/._04748.png
#   inflating: faces_dataset_small/04990.png
#   inflating: __MACOSX/faces_dataset_small/._04990.png
#   inflating: faces_dataset_small/02339.png
#   inflating: __MACOSX/faces_dataset_small/._02339.png
#   inflating: faces_dataset_small/03999.png
#   inflating: __MACOSX/faces_dataset_small/._03999.png
#   inflating: faces_dataset_small/00248.png
#   inflating: __MACOSX/faces_dataset_small/._00248.png
#   inflating: faces_dataset_small/03755.png
#   inflating: __MACOSX/faces_dataset_small/._03755.png
#   inflating: faces_dataset_small/03033.png
#   inflating: __MACOSX/faces_dataset_small/._03033.png
#   inflating: faces_dataset_small/04984.png
#   inflating: __MACOSX/faces_dataset_small/._04984.png
#   inflating: faces_dataset_small/01624.png
#   inflating: __MACOSX/faces_dataset_small/._01624.png
#   inflating: faces_dataset_small/04774.png
#   inflating: __MACOSX/faces_dataset_small/._04774.png
#   inflating: faces_dataset_small/02305.png
#   inflating: __MACOSX/faces_dataset_small/._02305.png
#   inflating: faces_dataset_small/00274.png
#   inflating: __MACOSX/faces_dataset_small/._00274.png
#   inflating: faces_dataset_small/02477.png
#   inflating: __MACOSX/faces_dataset_small/._02477.png
#   inflating: faces_dataset_small/03769.png
#   inflating: __MACOSX/faces_dataset_small/._03769.png
#   inflating: faces_dataset_small/00260.png
#   inflating: __MACOSX/faces_dataset_small/._00260.png
#   inflating: faces_dataset_small/01618.png
#   inflating: __MACOSX/faces_dataset_small/._01618.png
#   inflating: faces_dataset_small/04760.png
#   inflating: __MACOSX/faces_dataset_small/._04760.png
#   inflating: faces_dataset_small/02311.png
#   inflating: __MACOSX/faces_dataset_small/._02311.png
#   inflating: faces_dataset_small/00261.png
#   inflating: __MACOSX/faces_dataset_small/._00261.png
#   inflating: faces_dataset_small/03768.png
#   inflating: __MACOSX/faces_dataset_small/._03768.png
#   inflating: faces_dataset_small/02476.png
#   inflating: __MACOSX/faces_dataset_small/._02476.png
#   inflating: faces_dataset_small/02310.png
#   inflating: __MACOSX/faces_dataset_small/._02310.png
#   inflating: faces_dataset_small/04761.png
#   inflating: __MACOSX/faces_dataset_small/._04761.png
#   inflating: faces_dataset_small/01619.png
#   inflating: __MACOSX/faces_dataset_small/._01619.png
#   inflating: faces_dataset_small/02304.png
#   inflating: __MACOSX/faces_dataset_small/._02304.png
#   inflating: faces_dataset_small/04775.png
#   inflating: __MACOSX/faces_dataset_small/._04775.png
#   inflating: faces_dataset_small/04013.png
#   inflating: __MACOSX/faces_dataset_small/._04013.png
#   inflating: faces_dataset_small/00275.png
#   inflating: __MACOSX/faces_dataset_small/._00275.png
#   inflating: faces_dataset_small/03754.png
#   inflating: __MACOSX/faces_dataset_small/._03754.png
#   inflating: faces_dataset_small/01625.png
#   inflating: __MACOSX/faces_dataset_small/._01625.png
#   inflating: faces_dataset_small/04985.png
#   inflating: __MACOSX/faces_dataset_small/._04985.png
#   inflating: faces_dataset_small/02338.png
#   inflating: __MACOSX/faces_dataset_small/._02338.png
#   inflating: faces_dataset_small/04991.png
#   inflating: __MACOSX/faces_dataset_small/._04991.png
#   inflating: faces_dataset_small/04749.png
#   inflating: __MACOSX/faces_dataset_small/._04749.png
#   inflating: faces_dataset_small/01631.png
#   inflating: __MACOSX/faces_dataset_small/._01631.png
#   inflating: faces_dataset_small/00249.png
#   inflating: __MACOSX/faces_dataset_small/._00249.png
#   inflating: faces_dataset_small/03998.png
#   inflating: __MACOSX/faces_dataset_small/._03998.png
#   inflating: faces_dataset_small/03973.png
#   inflating: __MACOSX/faces_dataset_small/._03973.png
#   inflating: faces_dataset_small/01802.png
#   inflating: __MACOSX/faces_dataset_small/._01802.png
#   inflating: faces_dataset_small/01816.png
#   inflating: __MACOSX/faces_dataset_small/._01816.png
#   inflating: faces_dataset_small/03967.png
#   inflating: __MACOSX/faces_dataset_small/._03967.png
#   inflating: faces_dataset_small/01180.png
#   inflating: __MACOSX/faces_dataset_small/._01180.png
#   inflating: faces_dataset_small/02489.png
#   inflating: __MACOSX/faces_dataset_small/._02489.png
#   inflating: faces_dataset_small/03797.png
#   inflating: __MACOSX/faces_dataset_small/._03797.png
#   inflating: faces_dataset_small/04946.png
#   inflating: __MACOSX/faces_dataset_small/._04946.png
#   inflating: faces_dataset_small/04952.png
#   inflating: __MACOSX/faces_dataset_small/._04952.png
#   inflating: faces_dataset_small/03783.png
#   inflating: __MACOSX/faces_dataset_small/._03783.png
#   inflating: faces_dataset_small/01194.png
#   inflating: __MACOSX/faces_dataset_small/._01194.png
#   inflating: faces_dataset_small/00705.png
#   inflating: __MACOSX/faces_dataset_small/._00705.png
#   inflating: faces_dataset_small/04563.png
#   inflating: __MACOSX/faces_dataset_small/._04563.png
#   inflating: faces_dataset_small/02674.png
#   inflating: __MACOSX/faces_dataset_small/._02674.png
#   inflating: faces_dataset_small/04205.png
#   inflating: __MACOSX/faces_dataset_small/._04205.png
#   inflating: faces_dataset_small/01369.png
#   inflating: __MACOSX/faces_dataset_small/._01369.png
#   inflating: faces_dataset_small/02660.png
#   inflating: __MACOSX/faces_dataset_small/._02660.png
#   inflating: faces_dataset_small/04211.png
#   inflating: __MACOSX/faces_dataset_small/._04211.png
#   inflating: faces_dataset_small/00711.png
#   inflating: __MACOSX/faces_dataset_small/._00711.png
#   inflating: faces_dataset_small/00739.png
#   inflating: __MACOSX/faces_dataset_small/._00739.png
#   inflating: faces_dataset_small/02648.png
#   inflating: __MACOSX/faces_dataset_small/._02648.png
#   inflating: faces_dataset_small/02890.png
#   inflating: __MACOSX/faces_dataset_small/._02890.png
#   inflating: faces_dataset_small/03556.png
#   inflating: __MACOSX/faces_dataset_small/._03556.png
#   inflating: faces_dataset_small/02884.png
#   inflating: __MACOSX/faces_dataset_small/._02884.png
#   inflating: faces_dataset_small/01355.png
#   inflating: __MACOSX/faces_dataset_small/._01355.png
#   inflating: faces_dataset_small/00922.png
#   inflating: __MACOSX/faces_dataset_small/._00922.png
#   inflating: faces_dataset_small/02853.png
#   inflating: __MACOSX/faces_dataset_small/._02853.png
#   inflating: faces_dataset_small/03595.png
#   inflating: __MACOSX/faces_dataset_small/._03595.png
#   inflating: faces_dataset_small/01382.png
#   inflating: __MACOSX/faces_dataset_small/._01382.png
#   inflating: faces_dataset_small/01396.png
#   inflating: __MACOSX/faces_dataset_small/._01396.png
#   inflating: faces_dataset_small/02847.png
#   inflating: __MACOSX/faces_dataset_small/._02847.png
#   inflating: faces_dataset_small/03581.png
#   inflating: __MACOSX/faces_dataset_small/._03581.png
#   inflating: faces_dataset_small/00936.png
#   inflating: __MACOSX/faces_dataset_small/._00936.png
#   inflating: faces_dataset_small/00671.png
#   inflating: __MACOSX/faces_dataset_small/._00671.png
#   inflating: faces_dataset_small/01209.png
#   inflating: __MACOSX/faces_dataset_small/._01209.png
#   inflating: faces_dataset_small/00665.png
#   inflating: __MACOSX/faces_dataset_small/._00665.png
#   inflating: faces_dataset_small/00895.png
#   inflating: __MACOSX/faces_dataset_small/._00895.png
#   inflating: faces_dataset_small/01553.png
#   inflating: __MACOSX/faces_dataset_small/._01553.png
#   inflating: faces_dataset_small/01235.png
#   inflating: __MACOSX/faces_dataset_small/._01235.png
#   inflating: faces_dataset_small/03422.png
#   inflating: __MACOSX/faces_dataset_small/._03422.png
#   inflating: faces_dataset_small/03436.png
#   inflating: __MACOSX/faces_dataset_small/._03436.png
#   inflating: faces_dataset_small/02728.png
#   inflating: __MACOSX/faces_dataset_small/._02728.png
#   inflating: faces_dataset_small/01221.png
#   inflating: __MACOSX/faces_dataset_small/._01221.png
#   inflating: faces_dataset_small/00881.png
#   inflating: __MACOSX/faces_dataset_small/._00881.png
#   inflating: faces_dataset_small/01547.png
#   inflating: __MACOSX/faces_dataset_small/._01547.png
#   inflating: faces_dataset_small/03350.png
#   inflating: __MACOSX/faces_dataset_small/._03350.png
#   inflating: faces_dataset_small/00856.png
#   inflating: __MACOSX/faces_dataset_small/._00856.png
#   inflating: faces_dataset_small/01590.png
#   inflating: __MACOSX/faces_dataset_small/._01590.png
#   inflating: faces_dataset_small/03387.png
#   inflating: __MACOSX/faces_dataset_small/._03387.png
#   inflating: faces_dataset_small/02927.png
#   inflating: __MACOSX/faces_dataset_small/._02927.png
#   inflating: faces_dataset_small/02933.png
#   inflating: __MACOSX/faces_dataset_small/._02933.png
#   inflating: faces_dataset_small/03393.png
#   inflating: __MACOSX/faces_dataset_small/._03393.png
#   inflating: faces_dataset_small/00842.png
#   inflating: __MACOSX/faces_dataset_small/._00842.png
#   inflating: faces_dataset_small/01584.png
#   inflating: __MACOSX/faces_dataset_small/._01584.png
#   inflating: faces_dataset_small/02502.png
#   inflating: __MACOSX/faces_dataset_small/._02502.png
#   inflating: faces_dataset_small/04173.png
#   inflating: __MACOSX/faces_dataset_small/._04173.png
#   inflating: faces_dataset_small/04615.png
#   inflating: __MACOSX/faces_dataset_small/._04615.png
#   inflating: faces_dataset_small/02264.png
#   inflating: __MACOSX/faces_dataset_small/._02264.png
#   inflating: faces_dataset_small/00473.png
#   inflating: __MACOSX/faces_dataset_small/._00473.png
#   inflating: faces_dataset_small/01779.png
#   inflating: __MACOSX/faces_dataset_small/._01779.png
#   inflating: faces_dataset_small/00467.png
#   inflating: __MACOSX/faces_dataset_small/._00467.png
#   inflating: faces_dataset_small/04601.png
#   inflating: __MACOSX/faces_dataset_small/._04601.png
#   inflating: faces_dataset_small/02270.png
#   inflating: __MACOSX/faces_dataset_small/._02270.png
#   inflating: faces_dataset_small/02516.png
#   inflating: __MACOSX/faces_dataset_small/._02516.png
#   inflating: faces_dataset_small/03608.png
#   inflating: __MACOSX/faces_dataset_small/._03608.png
#   inflating: faces_dataset_small/03620.png
#   inflating: __MACOSX/faces_dataset_small/._03620.png
#   inflating: faces_dataset_small/01751.png
#   inflating: __MACOSX/faces_dataset_small/._01751.png
#   inflating: faces_dataset_small/01989.png
#   inflating: __MACOSX/faces_dataset_small/._01989.png
#   inflating: faces_dataset_small/04629.png
#   inflating: __MACOSX/faces_dataset_small/._04629.png
#   inflating: faces_dataset_small/02258.png
#   inflating: __MACOSX/faces_dataset_small/._02258.png
#   inflating: faces_dataset_small/03634.png
#   inflating: __MACOSX/faces_dataset_small/._03634.png
#   inflating: faces_dataset_small/03807.png
#   inflating: __MACOSX/faces_dataset_small/._03807.png
#   inflating: faces_dataset_small/01976.png
#   inflating: __MACOSX/faces_dataset_small/._01976.png
#   inflating: faces_dataset_small/01962.png
#   inflating: __MACOSX/faces_dataset_small/._01962.png
#   inflating: faces_dataset_small/03813.png
#   inflating: __MACOSX/faces_dataset_small/._03813.png
#   inflating: faces_dataset_small/04832.png
#   inflating: __MACOSX/faces_dataset_small/._04832.png
#   inflating: faces_dataset_small/01792.png
#   inflating: __MACOSX/faces_dataset_small/._01792.png
#   inflating: faces_dataset_small/00498.png
#   inflating: __MACOSX/faces_dataset_small/._00498.png
#   inflating: faces_dataset_small/01786.png
#   inflating: __MACOSX/faces_dataset_small/._01786.png
#   inflating: faces_dataset_small/04826.png
#   inflating: __MACOSX/faces_dataset_small/._04826.png
#   inflating: faces_dataset_small/04198.png
#   inflating: __MACOSX/faces_dataset_small/._04198.png
#   inflating: faces_dataset_small/04000/.DS_Store
#   inflating: __MACOSX/faces_dataset_small/04000/._.DS_Store

# %%
# !mkdir /content/data
# !mv /content/faces_dataset_small /content/data

# %%
# !pwd
# Out:
# /content

# %%
def get_dataloader(image_size, batch_size):
  """
  Builds dataloader for training data.
  Use tt.Compose and tt.Resize for transformations
  :param image_size: height and wdith of the image
  :param batch_size: batch_size of the dataloader
  :returns: DataLoader object 
  """
  train_folder = ImageFolder('/content/data', transform=tfs.Compose([
    tfs.Resize(image_size),
    tfs.CenterCrop(image_size),
    tfs.ToTensor()
    ]))
  data_loader = DataLoader(train_folder, batch_size, num_workers=2)
  return data_loader

# %%
image_size = 128
batch_size = 128
train_data = get_dataloader(image_size, 32)

# %%
stats = (0.5, 0.5, 0.5), (0.5, 0.5, 0.5)

def denorm(img_tensors):
    return img_tensors * stats[1][0] + stats[0][0]

def show_images(images, nmax=64):
    fig, ax = plt.subplots(figsize=(8, 8))
    ax.set_xticks([]); ax.set_yticks([])
    ax.imshow(make_grid(denorm(images.detach()[:nmax]), nrow=8).permute(1, 2, 0))

def show_batch(dl, nmax=64):
    for images, _ in dl:
        show_images(images, nmax)
        break
      
show_batch(train_data)

# %% [markdown]
# ## Часть 2. Построение и обучение модели (2 балла)

# %% [markdown]
# Сконструируйте генератор и дискриминатор. Помните, что:
# * дискриминатор принимает на вход изображение (тензор размера `3 x image_size x image_size`) и выдает вероятность того, что изображение настоящее (тензор размера 1)
#
# * генератор принимает на вход тензор шумов размера `latent_size x 1 x 1` и генерирует изображение размера `3 x image_size x image_size`

# %%
discriminator = nn.Sequential(
    # in: 3 x 64 x 64

    nn.Conv2d(3, 64, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(64),
    nn.LeakyReLU(0.2, inplace=True),
    # out: 64 x 32 x 32

    nn.Conv2d(64, 128, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(128),
    nn.LeakyReLU(0.2, inplace=True),
    # out: 128 x 16 x 16

    nn.Conv2d(128, 256, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(256),
    nn.LeakyReLU(0.2, inplace=True),
    # out: 256 x 8 x 8

    nn.Conv2d(256, 512, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(512),
    nn.LeakyReLU(0.2, inplace=True),
    # out: 512 x 4 x 4

    nn.Conv2d(512, 1, kernel_size=4, stride=1, padding=0, bias=False),
    # out: 1 x 1 x 1

    nn.Flatten(),
    nn.Sigmoid())

# %%
latent_size = 128

generator = nn.Sequential(
    # in: latent_size x 1 x 1

    nn.ConvTranspose2d(latent_size, 512, kernel_size=4, stride=1, padding=0, bias=False),
    nn.BatchNorm2d(512),
    nn.ReLU(True),
    # out: 512 x 4 x 4

    nn.ConvTranspose2d(512, 256, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(256),
    nn.ReLU(True),
    # out: 256 x 8 x 8

    nn.ConvTranspose2d(256, 128, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(128),
    nn.ReLU(True),
    # out: 128 x 16 x 16

    nn.ConvTranspose2d(128, 64, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(64),
    nn.ReLU(True),
    # out: 64 x 32 x 32

    nn.ConvTranspose2d(64, 3, kernel_size=4, stride=2, padding=1, bias=False),
    nn.Tanh()
    # out: 3 x 64 x 64
)

xb = torch.randn(batch_size, latent_size, 1, 1) 
fake_images = generator(xb)
print(fake_images.shape)
show_images(fake_images)
# Out:
# torch.Size([32, 3, 64, 64])

# %% [markdown]
# Перейдем теперь к обучению нашего GANа. Алгоритм обучения следующий:
# 1. Учим дискриминатор:
#   * берем реальные изображения и присваиваем им метку 1
#   * генерируем изображения генератором и присваиваем им метку 0
#   * обучаем классификатор на два класса
#
# 2. Учим генератор:
#   * генерируем изображения генератором и присваиваем им метку 0
#   * предсказываем дискриминаторором, реальное это изображение или нет
#
#
# В качестве функции потерь берем бинарную кросс-энтропию

# %%
device = 'cuda'

lr = 0.0001
discriminator = discriminator.to(device)
generator = generator.to(device)

model = {
    "discriminator": discriminator,
    "generator": generator
}

criterion = {
    "discriminator": nn.BCELoss(),
    "generator": nn.BCELoss()
}

# %%
sample_dir = '/content/generated'
os.makedirs(sample_dir, exist_ok=True)

def save_samples(index, latent_tensors, show=True):
    fake_images = generator(latent_tensors)
    fake_fname = 'generated-images-{0:0=4d}.png'.format(index)
    save_image(denorm(fake_images), os.path.join(sample_dir, fake_fname), nrow=8)
    print('Saving', fake_fname)
    if show:
        fig, ax = plt.subplots(figsize=(8, 8))
        ax.set_xticks([]); ax.set_yticks([])
        ax.imshow(make_grid(fake_images.cpu().detach(), nrow=8).permute(1, 2, 0))

# %%
def fit(model, criterion, epochs, lr, start_idx=1):
    model["discriminator"].train()
    model["generator"].train()
    torch.cuda.empty_cache()
    
    # Losses & scores
    losses_g = []
    losses_d = []
    real_scores = []
    fake_scores = []
    
    # Create optimizers
    optimizer = {
        "discriminator": torch.optim.Adam(model["discriminator"].parameters(), 
                                          lr=lr, betas=(0.5, 0.999)),
        "generator": torch.optim.Adam(model["generator"].parameters(),
                                      lr=lr, betas=(0.5, 0.999))
    }
    
    for epoch in range(epochs):
        loss_d_per_epoch = []
        loss_g_per_epoch = []
        real_score_per_epoch = []
        fake_score_per_epoch = []
        for real_images, _ in tqdm(train_data):
            # Train discriminator
            # Clear discriminator gradients
            optimizer["discriminator"].zero_grad()

            # Pass real images through discriminator
            real_images = real_images.to(device)
            real_preds = model["discriminator"](real_images)
            real_targets = torch.ones(real_images.size(0), 25, device=device)
            real_loss = criterion["discriminator"](real_preds, real_targets)
            cur_real_score = torch.mean(real_preds).item()
            
            # Generate fake images
            latent = torch.randn(batch_size, latent_size, 1, 1, device=device)
            fake_images = model["generator"](latent)

            # Pass fake images through discriminator
            fake_targets = torch.zeros(fake_images.size(0), 1, device=device)
            fake_preds = model["discriminator"](fake_images)
            fake_loss = criterion["discriminator"](fake_preds, fake_targets)
            cur_fake_score = torch.mean(fake_preds).item()

            real_score_per_epoch.append(cur_real_score)
            fake_score_per_epoch.append(cur_fake_score)

            # Update discriminator weights
            loss_d = real_loss + fake_loss
            loss_d.backward()
            optimizer["discriminator"].step()
            loss_d_per_epoch.append(loss_d.item())


            # Train generator
            # Clear generator gradients
            optimizer["generator"].zero_grad()
            
            # Generate fake images
            latent = torch.randn(batch_size, latent_size, 1, 1, device=device)
            fake_images = model["generator"](latent)
            
            # Try to fool the discriminator
            preds = model["discriminator"](fake_images)
            targets = torch.ones(batch_size, 1, device=device)
            loss_g = criterion["generator"](preds, targets)
            
            # Update generator weights
            loss_g.backward()
            optimizer["generator"].step()
            loss_g_per_epoch.append(loss_g.item())
            
        # Record losses & scores
        losses_g.append(np.mean(loss_g_per_epoch))
        losses_d.append(np.mean(loss_d_per_epoch))
        real_scores.append(np.mean(real_score_per_epoch))
        fake_scores.append(np.mean(fake_score_per_epoch))
        
        # Log losses & scores (last batch)
        print("Epoch [{}/{}], loss_g: {:.4f}, loss_d: {:.4f}, real_score: {:.4f}, fake_score: {:.4f}".format(
            epoch+1, epochs, 
            losses_g[-1], losses_d[-1], real_scores[-1], fake_scores[-1]))
    
        # Save generated images
        if epoch == epochs - 1:
          save_samples(epoch+start_idx, fixed_latent, show=False)
    
    return losses_g, losses_d, real_scores, fake_scores

# %%
n_epochs = 10

a = fit(model, criterion, n_epochs, lr)
# Out:
#   0%|          | 0/99 [00:00<?, ?it/s]
# Epoch [1/10], loss_g: 7.4123, loss_d: 0.0342, real_score: 0.9804, fake_score: 0.0121
#   0%|          | 0/99 [00:00<?, ?it/s]
# Epoch [2/10], loss_g: 8.7093, loss_d: 0.0028, real_score: 0.9982, fake_score: 0.0010
#   0%|          | 0/99 [00:00<?, ?it/s]
# Epoch [3/10], loss_g: 8.6754, loss_d: 0.0007, real_score: 0.9996, fake_score: 0.0003
#   0%|          | 0/99 [00:00<?, ?it/s]
# Epoch [4/10], loss_g: 9.0318, loss_d: 0.0005, real_score: 0.9998, fake_score: 0.0002
#   0%|          | 0/99 [00:00<?, ?it/s]
# Epoch [5/10], loss_g: 9.1762, loss_d: 0.0003, real_score: 0.9998, fake_score: 0.0002
#   0%|          | 0/99 [00:00<?, ?it/s]
# Epoch [6/10], loss_g: 9.2363, loss_d: 0.0002, real_score: 0.9999, fake_score: 0.0001
#   0%|          | 0/99 [00:00<?, ?it/s]
# Epoch [7/10], loss_g: 9.4906, loss_d: 0.0002, real_score: 0.9999, fake_score: 0.0001
#   0%|          | 0/99 [00:00<?, ?it/s]
# Epoch [8/10], loss_g: 9.8968, loss_d: 0.0001, real_score: 0.9999, fake_score: 0.0001
#   0%|          | 0/99 [00:00<?, ?it/s]
# Epoch [9/10], loss_g: 10.0179, loss_d: 0.0001, real_score: 0.9999, fake_score: 0.0001
#   0%|          | 0/99 [00:00<?, ?it/s]
# Epoch [10/10], loss_g: 10.1210, loss_d: 0.0001, real_score: 1.0000, fake_score: 0.0001
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-28-0de71243900f> in <module>()
#       1 n_epochs = 10
#       2
# ----> 3 a = fit(model, criterion, n_epochs, lr)
#
# <ipython-input-27-cf1de351a3b1> in fit(model, criterion, epochs, lr, start_idx)
#      86         # Save generated images
#      87         if epoch == epochs - 1:
# ---> 88           save_samples(epoch+start_idx, fixed_latent, show=False)
#      89
#      90     return losses_g, losses_d, real_scores, fake_scores
#
# NameError: name 'fixed_latent' is not defined

# %% [markdown]
# Постройте графики лосса для генератора и дискриминатора. Что вы можете сказать про эти графики?

# %% [markdown]
# ## Часть 3. Генерация изображений (1 балл)

# %% [markdown]
# Теперь давайте оценим качество получившихся изображений. Напишите функцию, которая выводит изображения, сгенерированные нашим генератором

# %%
n_images = 4
n_epochs = 10

fixed_latent = torch.randn(n_images, latent_size, 1, 1, device=device)
fake_images = model["generator"](fixed_latent)

# %%
fake_images = fake_images.detach().cpu().numpy()

# %%
fake_images[0].shape
# Out:
# (3, 64, 64)

# %%
fig, ax = plt.subplots(figsize=(8, 8))
ax.set_xticks([]); ax.set_yticks([])
ax.imshow(fake_images[0].transpose(1, 2, 0))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
def show_images(generated, criterion, n_epochs, ):
  
  pass

# %% [markdown]
# Как вам качество получившихся изображений?

# %% [markdown]
# ## Часть 4. Leave-one-out-1-NN classifier accuracy (6 баллов)

# %% [markdown]
# ### 4.1. Подсчет accuracy (4 балла)

# %% [markdown]
# Не всегда бывает удобно оценивать качество сгенерированных картинок глазами. В качестве альтернативы вам предлагается реализовать следующий подход:
#   * Сгенерировать столько же фейковых изображений, сколько есть настоящих в обучающей выборке. Присвоить фейковым метку класса 0, настоящим – 1.
#   * Построить leave-one-out оценку: обучить 1NN Classifier (`sklearn.neighbors.KNeighborsClassifier(n_neighbors=1)`) предсказывать класс на всех объектах, кроме одного, проверить качество (accuracy) на оставшемся объекте. В этом вам поможет `sklearn.model_selection.LeaveOneOut`

# %% [markdown]
# Что вы можете сказать о получившемся результате? Какой accuracy мы хотели бы получить и почему?

# %% [markdown]
# ### 4.2. Визуализация распределений (2 балла)

# %% [markdown]
# Давайте посмотрим на то, насколько похожи распределения настоящих и фейковых изображений. Для этого воспользуйтесь методом, снижающим размерность (к примеру, TSNE) и изобразите на графике разным цветом точки, соответствующие реальным и сгенерированным изображенияи

# %% [markdown]
# Прокомментируйте получившийся результат:
